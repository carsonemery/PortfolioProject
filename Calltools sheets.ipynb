# %%
import pandas as pd
import numpy as np
import os
import xlrd
import openpyxl
from pathlib import Path

# %%
pwd = os.getcwd() 
# this is telling the library "OS" to use the current working directory, which is the folder we are working out of
# this also allows you to pull the same file from different locations if you move the file around, by calling "pwd"

# %%
# filepath1 = pwd + "/Calltools Semiannual followup.csv"

# %%
# netflix = pd.read_csv(pwd + "/netflix_titles.csv")
# netflix

# %%
semiannual = pd.read_csv(pwd + "/Calltools Semiannual followup.csv")
SOI = pd.read_csv(pwd + "/Calltools SOI.csv")
yearly = pd.read_csv(pwd + "/Calltools yearly followup.csv")

# %%
semiannual.head()
# Out:
#    phone_number  first_name last_name  company_name               address  \
# 0   13852267606      Robert    Waters           NaN         2850 S 700 E
# 1   17188122212  Esperanza    Becerra           NaN        2799 E 3900 S
# 2   18015989585      Robert    Tyrell           NaN         157 S 1200 E
# 3   18012809328      Modell   Lambson           NaN  3681 W Winthrope Cir
# 4   12064270015      Harold   Pugmire           NaN           660 N 600 E
#
#   address2            city state  zip_code  alternate_number  ...  \
# 0      NaN  Salt Lake City    UT     84106               NaN  ...
# 1      NaN  Salt Lake City    UT     84124               NaN  ...
# 2      NaN  Salt Lake City    UT     84102               NaN  ...
# 3      NaN     West Jordan    UT     84088               NaN  ...
# 4      NaN           Provo    UT     84606               NaN  ...
#
#    Asking Price  Zillow Price  Lead Type PropertySpec Condition dials  \
# ...

# %%
semiannual = semiannual.drop(columns=['Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'])
semiannual
# Out:
#     phone_number                        first_name  \
# 0    13852267606                            Robert
# 1    17188122212                        Esperanza
# 2    18015989585                            Robert
# 3    18012809328                            Modell
# 4    12064270015                            Harold
# 5    13106225037                             CAMEO
# 6    18019318653                           MICHAEL
# 7    18019103585                            JOSHUA
# 8    18016645818                            Mercer
# 9    18017562088                           MARILYN
# 10   17203232304                           Raymond
# 11   18013214843                             Lorin
# 12   18018562466                       CHRISTOPHER
# 13   18014678186  PAOLA  felice   paolas brother
# 14   18015089412                          CLIFFORD
# 15   18015312199                           Douglas
# 16   18013632360                          MARJORIE
# ...

# %%
list(semiannual.columns)
# Out:
# ['phone_number',
#  'first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'address2',
#  'city',
#  'state',
#  'zip_code',
#  'alternate_number',
#  'mobile_number',
#  'email_address',
#  'notes',
#  'dispositions',
#  'assigned_to',
#  'date_created',
#  'Timeline',
#  'Motivation',
#  'Asking Price',
#  'Zillow Price',
#  'Lead Type',
#  'PropertySpec',
#  'Condition',
#  'dials',
#  'Unnamed: 27']

# %%
try:
    semiannual = semiannual.drop(columns=['PropertySpec', 'Condition', 'dials', 'Lead Type', 'Zillow Price', 'Asking Price', 'Motivation', 'Timeline', 'date_created', 'assigned_to', 'dispotitions', 'email_address'])
except KeyError:
    pass
semiannual
# Out:
#     phone_number                        first_name  \
# 0    13852267606                            Robert
# 1    17188122212                        Esperanza
# 2    18015989585                            Robert
# 3    18012809328                            Modell
# 4    12064270015                            Harold
# 5    13106225037                             CAMEO
# 6    18019318653                           MICHAEL
# 7    18019103585                            JOSHUA
# 8    18016645818                            Mercer
# 9    18017562088                           MARILYN
# 10   17203232304                           Raymond
# 11   18013214843                             Lorin
# 12   18018562466                       CHRISTOPHER
# 13   18014678186  PAOLA  felice   paolas brother
# 14   18015089412                          CLIFFORD
# 15   18015312199                           Douglas
# 16   18013632360                          MARJORIE
# ...

# %%
list(semiannual.columns)
# Out:
# ['phone_number',
#  'first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'address2',
#  'city',
#  'state',
#  'zip_code',
#  'alternate_number',
#  'mobile_number',
#  'email_address',
#  'notes',
#  'dispositions',
#  'assigned_to',
#  'date_created',
#  'Timeline',
#  'Motivation',
#  'Asking Price',
#  'Zillow Price',
#  'Lead Type',
#  'PropertySpec',
#  'Condition',
#  'dials',
#  'Unnamed: 27']

# %%
# try:
semiannual = semiannual.drop(columns=['alternate_number', 'email_address', 'dispositions', 'assigned_to', 'date_created', 'Timeline', 'Motivation', 'Asking Price', 'Zillow Price', 'Lead Type', 'PropertySpec', 'Condition', 'dials'])
# except KeyError:
#    pass
semiannual
# Out:
#     phone_number                        first_name  \
# 0    13852267606                            Robert
# 1    17188122212                        Esperanza
# 2    18015989585                            Robert
# 3    18012809328                            Modell
# 4    12064270015                            Harold
# 5    13106225037                             CAMEO
# 6    18019318653                           MICHAEL
# 7    18019103585                            JOSHUA
# 8    18016645818                            Mercer
# 9    18017562088                           MARILYN
# 10   17203232304                           Raymond
# 11   18013214843                             Lorin
# 12   18018562466                       CHRISTOPHER
# 13   18014678186  PAOLA  felice   paolas brother
# 14   18015089412                          CLIFFORD
# 15   18015312199                           Douglas
# 16   18013632360                          MARJORIE
# ...

# %%
list(semiannual.columns)
# Out:
# ['phone_number',
#  'first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'address2',
#  'city',
#  'state',
#  'zip_code',
#  'mobile_number',
#  'notes',
#  'Unnamed: 27']

# %%
list(semiannual.columns)
# semiannual = semiannual.drop(columns=['company_name', 'address2'])
# Out:
# ['phone_number',
#  'first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'address2',
#  'city',
#  'state',
#  'zip_code',
#  'mobile_number',
#  'notes',
#  'Unnamed: 27']

# %%
semiannual
# Out:
#     phone_number                        first_name  \
# 0    13852267606                            Robert
# 1    17188122212                        Esperanza
# 2    18015989585                            Robert
# 3    18012809328                            Modell
# 4    12064270015                            Harold
# 5    13106225037                             CAMEO
# 6    18019318653                           MICHAEL
# 7    18019103585                            JOSHUA
# 8    18016645818                            Mercer
# 9    18017562088                           MARILYN
# 10   17203232304                           Raymond
# 11   18013214843                             Lorin
# 12   18018562466                       CHRISTOPHER
# 13   18014678186  PAOLA  felice   paolas brother
# 14   18015089412                          CLIFFORD
# 15   18015312199                           Douglas
# 16   18013632360                          MARJORIE
# ...

# %%
semiannual = semiannual.drop(columns=['company_name', 'address2', 'mobile_number', 'notes'])

# %%
semiannual
# Out:
#     phone_number                        first_name  \
# 0    13852267606                            Robert
# 1    17188122212                        Esperanza
# 2    18015989585                            Robert
# 3    18012809328                            Modell
# 4    12064270015                            Harold
# 5    13106225037                             CAMEO
# 6    18019318653                           MICHAEL
# 7    18019103585                            JOSHUA
# 8    18016645818                            Mercer
# 9    18017562088                           MARILYN
# 10   17203232304                           Raymond
# 11   18013214843                             Lorin
# 12   18018562466                       CHRISTOPHER
# 13   18014678186  PAOLA  felice   paolas brother
# 14   18015089412                          CLIFFORD
# 15   18015312199                           Douglas
# 16   18013632360                          MARJORIE
# ...

# %%
list(semiannual.columns)
# Out:
# ['phone_number',
#  'first_name',
#  'last_name',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'Unnamed: 27']

# %%
list(SOI.columns)
# Out:
# ['phone_number',
#  'first_name',
#  'last_name',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11']

# %%
SOI.head()
# Out:
#    phone_number first_name                   last_name              address  \
# 0   18015725673   Barbara                         Kobs    9732 S Poppy Lane
# 1   17038301732    MICHAEL                     WARTHER         2300 S 700 E
# 2   18016996711       ANDY                       MIERA         3172 S 500 E
# 3   18015010671       ANDY                       MIERA         3172 S 500 E
# 4   18015404142        NaN  A STUART WHEELWRIGHT TRUST  2420 Bonneville Ter
#
#              city state  zip_code  \
# 0          Sandy     UT     84094
# 1  Salt Lake City    UT     84106
# 2  Salt Lake City    UT     84106
# 3  Salt Lake City    UT     84106
# 4           Ogden    UT     84403
#
#                                           Unnamed: 7  Unnamed: 8  \
# 0  Her and her 3 siblings are fixing up their 92 ...         NaN
# 1  cool guy  worked for bush  owns multiple solar...         NaN
# 2  just fixed up the one up on 500 E that he will...         NaN
# ...

# %%
SOI.loc

# %%
SOI.head(10)
# Out:
#    phone_number  first_name                   last_name              address  \
# 0   18015725673    Barbara                         Kobs    9732 S Poppy Lane
# 1   17038301732     MICHAEL                     WARTHER         2300 S 700 E
# 2   18016996711        ANDY                       MIERA         3172 S 500 E
# 3   18015010671        ANDY                       MIERA         3172 S 500 E
# 4   18015404142         NaN  A STUART WHEELWRIGHT TRUST  2420 Bonneville Ter
# 5   18013588617        MARK                      WILSON      869 W Center St
# 6   18016032538     Abraham                     Aguilar   197 Meadow View Dr
# 7   18014558822  Kim Gherig                  Stevenson      1612 E Park Pl N
# 8   18019106566      BRENDA                    THOMPSON        3321 S 3690 W
# 9   18502261317        JUNE                      BOSTON   1597 S Richards St
#
#                city state  zip_code  \
# 0            Sandy     UT     84094
# 1    Salt Lake City    UT     84106
# ...

# %%
# this is another way to select columns, instead of using drop method I can just create a new dataframe where I select the data I want using loc.
SOI = SOI.loc[:, 'phone_number':'Unnamed: 7']

# %%
SOI.head(5)
# Out:
#    phone_number first_name                   last_name              address  \
# 0   18015725673   Barbara                         Kobs    9732 S Poppy Lane
# 1   17038301732    MICHAEL                     WARTHER         2300 S 700 E
# 2   18016996711       ANDY                       MIERA         3172 S 500 E
# 3   18015010671       ANDY                       MIERA         3172 S 500 E
# 4   18015404142        NaN  A STUART WHEELWRIGHT TRUST  2420 Bonneville Ter
#
#              city state  zip_code  \
# 0          Sandy     UT     84094
# 1  Salt Lake City    UT     84106
# 2  Salt Lake City    UT     84106
# 3  Salt Lake City    UT     84106
# 4           Ogden    UT     84403
#
#                                           Unnamed: 7
# 0  Her and her 3 siblings are fixing up their 92 ...
# 1  cool guy  worked for bush  owns multiple solar...
# 2  just fixed up the one up on 500 E that he will...
# 3  rented at 1200  owes around 30k  hands are ful...
# ...

# %%
semiannual.head(5)
# Out:
#    phone_number  first_name last_name               address            city  \
# 0   13852267606      Robert    Waters         2850 S 700 E   Salt Lake City
# 1   17188122212  Esperanza    Becerra        2799 E 3900 S   Salt Lake City
# 2   18015989585      Robert    Tyrell         157 S 1200 E   Salt Lake City
# 3   18012809328      Modell   Lambson  3681 W Winthrope Cir     West Jordan
# 4   12064270015      Harold   Pugmire           660 N 600 E           Provo
#
#   state  zip_code                                        Unnamed: 27
# 0    UT     84106  goes by bob waters  had a lien for 10k owes ar...
# 1    UT     84124  vacant property but says she doesnt want to se...
# 2    UT     84102  unit 1 $1300  3 bed  unit 2 $1050 2 bed  would...
# 3    UT     84088  Rental Property  hasnt been there in a while  ...
# 4    UT     84606  moved from seattle washington  this property h...

# %%
frames = [SOI, semiannual]
result = pd.concat(frames)

# %%
result
# Out:
#     phone_number     first_name                   last_name  \
# 0    18015725673       Barbara                         Kobs
# 1    17038301732        MICHAEL                     WARTHER
# 2    18016996711           ANDY                       MIERA
# 3    18015010671           ANDY                       MIERA
# 4    18015404142            NaN  A STUART WHEELWRIGHT TRUST
# ..           ...            ...                         ...
# 53   18014338576        FATEMEH                   LAVASANIE
# 54   18015504461         NORMAN                   HENDERSON
# 55   18013192817           FRED                     JOHNSON
# 56   18018510982          DUANE                      PAXTON
# 57   18015923530  ADAM  joselyn                  SODERSTROM
#
#                        address            city state  zip_code  \
# 0            9732 S Poppy Lane          Sandy     UT     84094
# 1                 2300 S 700 E  Salt Lake City    UT     84106
# ...

# %%
yearly.head()
# Out:
#    phone_number    first_name  last_name  company_name              address  \
# 0  1.801915e+10        Garry      Nelson           NaN  800 E Willowood Ave
# 1  1.801337e+10       SHANNON      ALVEY           NaN          265 N 600 W
# 2  1.309339e+10        VERNON  BERGSTROM           NaN     5210 Old Post Rd
# 3  1.801244e+10   BRIAN  Sara  GETZELMAN           NaN         2304 S 800 E
# 4  1.801475e+10  WILLIAM  kim    RAYMOND           NaN         132 W 4575 S
#
#   address2            city state  zip_code  \
# 0      NaN  Salt Lake City    UT   84107.0
# 1      NaN  Salt Lake City    UT   84116.0
# 2      NaN           Ogden    UT   84403.0
# 3      NaN  Salt Lake City    UT   84106.0
# 4      NaN           Ogden    UT   84405.0
#
#                                           Unnamed: 9  \
# 0  yearly followup;2020-06-18 14:19:13-06:00,"Sem...
# 1  says she recently got some bad health news  sa...
# 2  spoke to joy vernons daughter who said they mi...
# ...

# %%
print("\n Total number of columns :", len(yearly.axes[1]))
# Out:
#  Total number of columns : 12

# %%
len(yearly)
# Out:
# 40

# %%
# SOI = SOI.loc[:, 'phone_number':'Unnamed: 7']
yearly = yearly.drop(columns=['company_name', 'address2'])
yearly.head()
# Out:
#    phone_number    first_name  last_name              address            city  \
# 0  1.801915e+10        Garry      Nelson  800 E Willowood Ave  Salt Lake City
# 1  1.801337e+10       SHANNON      ALVEY          265 N 600 W  Salt Lake City
# 2  1.309339e+10        VERNON  BERGSTROM     5210 Old Post Rd           Ogden
# 3  1.801244e+10   BRIAN  Sara  GETZELMAN         2304 S 800 E  Salt Lake City
# 4  1.801475e+10  WILLIAM  kim    RAYMOND         132 W 4575 S           Ogden
#
#   state  zip_code                                         Unnamed: 9  \
# 0    UT   84107.0  yearly followup;2020-06-18 14:19:13-06:00,"Sem...
# 1    UT   84116.0  says she recently got some bad health news  sa...
# 2    UT   84403.0  spoke to joy vernons daughter who said they mi...
# 3    UT   84106.0  semi retired  2  1 bed apts in it  says atkins...
# 4    UT   84405.0  have renters  that want to buy it  said they m...
#
#    yellow means spoke with, not ready   \
# ...

# %%
yearly.rename(columns={'yellow means spoke with, not ready': 'drop1'}, inplace=True)

# %%
yearly.head(5)
# Out:
#    phone_number    first_name  last_name              address            city  \
# 0  1.801915e+10        Garry      Nelson  800 E Willowood Ave  Salt Lake City
# 1  1.801337e+10       SHANNON      ALVEY          265 N 600 W  Salt Lake City
# 2  1.309339e+10        VERNON  BERGSTROM     5210 Old Post Rd           Ogden
# 3  1.801244e+10   BRIAN  Sara  GETZELMAN         2304 S 800 E  Salt Lake City
# 4  1.801475e+10  WILLIAM  kim    RAYMOND         132 W 4575 S           Ogden
#
#   state  zip_code                                         Unnamed: 9  \
# 0    UT   84107.0  yearly followup;2020-06-18 14:19:13-06:00,"Sem...
# 1    UT   84116.0  says she recently got some bad health news  sa...
# 2    UT   84403.0  spoke to joy vernons daughter who said they mi...
# 3    UT   84106.0  semi retired  2  1 bed apts in it  says atkins...
# 4    UT   84405.0  have renters  that want to buy it  said they m...
#
#    yellow means spoke with, not ready   \
# ...

# %%
list(yearly.columns)
# Out:
# ['phone_number',
#  'first_name',
#  'last_name',
#  'address',
#  'city',
#  'state',
#  'zip_code',
#  'Unnamed: 9',
#  'yellow means spoke with, not ready ',
#  'orange means called no answer']

# %%
yearly = yearly.drop(columns=['yellow means spoke with, not ready ', 'orange means called no answer'])

# %%
yearly
# Out:
#     phone_number                first_name            last_name  \
# 0   1.801915e+10                    Garry                Nelson
# 1   1.801337e+10                   SHANNON                ALVEY
# 2   1.309339e+10                    VERNON            BERGSTROM
# 3   1.801244e+10               BRIAN  Sara            GETZELMAN
# 4   1.801475e+10              WILLIAM  kim              RAYMOND
# 5   1.435779e+10                    GEORGE                OLSON
# 6   1.801350e+10                     WAYNE             BLACKHAM
# 7   1.435830e+10  REBECCA  Britney & Miles                 PACK
# 8   1.801860e+10                       KIM             BROOKSBY
# 9   1.801968e+10                    DANIEL              RYDALCH
# 10  1.801860e+10               John  emily                 Tani
# 11  1.801450e+10              MIKE  WENDY               SCHMIDT
# 12  1.801686e+10                      DAVE                BATES
# 13  1.801331e+10                     JACEK            KOWALCZYK
# ...

# %%
yearly = yearly.loc[:35, :]
yearly
# Out:
#     phone_number                first_name            last_name  \
# 0   1.801915e+10                    Garry                Nelson
# 1   1.801337e+10                   SHANNON                ALVEY
# 2   1.309339e+10                    VERNON            BERGSTROM
# 3   1.801244e+10               BRIAN  Sara            GETZELMAN
# 4   1.801475e+10              WILLIAM  kim              RAYMOND
# 5   1.435779e+10                    GEORGE                OLSON
# 6   1.801350e+10                     WAYNE             BLACKHAM
# 7   1.435830e+10  REBECCA  Britney & Miles                 PACK
# 8   1.801860e+10                       KIM             BROOKSBY
# 9   1.801968e+10                    DANIEL              RYDALCH
# 10  1.801860e+10               John  emily                 Tani
# 11  1.801450e+10              MIKE  WENDY               SCHMIDT
# 12  1.801686e+10                      DAVE                BATES
# 13  1.801331e+10                     JACEK            KOWALCZYK
# ...

# %%
frames2 = [SOI, semiannual, yearly]
result = pd.concat(frames2)
result
# Out:
#     phone_number      first_name                   last_name  \
# 0   1.801573e+10        Barbara                         Kobs
# 1   1.703830e+10         MICHAEL                     WARTHER
# 2   1.801700e+10            ANDY                       MIERA
# 3   1.801501e+10            ANDY                       MIERA
# 4   1.801540e+10             NaN  A STUART WHEELWRIGHT TRUST
# ..           ...             ...                         ...
# 30  1.801673e+10   William  Bill                    Popadich
# 31  1.480696e+10           James                         Bay
# 32  1.801713e+10  Bryant  debbie                       Hafer
# 33  1.435650e+10          DUNCAN                      SILVER
# 34  1.801824e+10         MICHEAL                      TOTTEN
#
#                             address              city state  zip_code  \
# 0                 9732 S Poppy Lane            Sandy     UT   84094.0
# 1                      2300 S 700 E    Salt Lake City    UT   84106.0
# ...

# %%
result.to_excel(r'C:\Users\CarsonEmery\Python Programs\call tools sheets\File Name.xlsx', index = False)
